# %% [markdown]
# # ML Zoomcamp 2025 — Module 1 Homework
#
# Dataset: [Car Fuel Efficiency](https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv)
#
# Full instructions: [[Courses/machine-learning-zoomcamp/cohorts/2025/01-intro/homework.md]]

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Q1. Pandas version
#
# What version of Pandas did you install?

# %%
pd.__version__
# Out:
# '3.0.1'

# %% [markdown]
# ## Getting the data
#
# Download the dataset and read it with Pandas.

# %%
url = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv'
df = pd.read_csv(url)
df.head(100)

# %% [markdown]
# ## Q2. Records count
#
# How many records are in the dataset?
#
# - 4704
# - 8704
# - 9704
# - 17704

# %%
df.count()
# 9704
# Out:
# engine_displacement    9704
# num_cylinders          9222
# horsepower             8996
# vehicle_weight         9704
# acceleration           8774
# model_year             9704
# origin                 9704
# fuel_type              9704
# drivetrain             9704
# num_doors              9202
# fuel_efficiency_mpg    9704
# dtype: int64

# %% [markdown]
# ## Q3. Fuel types
#
# How many fuel types are presented in the dataset?
#
# - 1
# - 2
# - 3
# - 4

# %%
df.groupby("fuel_type").acceleration.mean()
# 2
# Out:
# fuel_type
# Diesel      15.030943
# Gasoline    15.013065
# Name: acceleration, dtype: float64

# %% [markdown]
# ## Q4. Missing values
#
# How many columns in the dataset have missing values?
#
# - 0
# - 1
# - 2
# - 3
# - 4

# %%
df.isnull().sum()
# 4
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# ## Q5. Max fuel efficiency
#
# What's the maximum fuel efficiency of cars from Asia?
#
# - 13.75
# - 23.75
# - 33.75
# - 43.75

# %%
df[
    df['origin'] == 'Asia'
].fuel_efficiency_mpg.max()

# 23.75
# Out:
# np.float64(23.759122836520497)

# %% [markdown]
# ## Q6. Median value of horsepower
#
# 1. Find the median value of the `horsepower` column in the dataset.
# 2. Next, calculate the most frequent value of the same `horsepower` column.
# 3. Use `fillna` to fill the missing values in `horsepower` with the most frequent value from the previous step.
# 4. Now, calculate the median value of `horsepower` once again.
#
# Has it changed?
#
# - Yes, it increased
# - Yes, it decreased
# - No

# %%
float(df['horsepower'].median())
# Out:
# 149.0

# %% [markdown]
# ## Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns `vehicle_weight` and `model_year`
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it `X`.
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X` (`X.T`). Call the result `XTX`.
# 6. Invert `XTX`.
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.
# 8. Multiply the inverse of `XTX` with the transpose of `X`, then multiply the result by `y`. Call the result `w`.
# 9. What's the sum of all the elements of the result?
#
# > **Note**: You just implemented linear regression. We'll talk about it in the next lesson.
#
# - 0.051
# - 0.51
# - 5.1
# - 51

# %%
df_asia = df[
    df['origin'] == 'Asia'
]

X = df_asia[['vehicle_weight', 'model_year']].head(7).values

XTX = X.T.dot(X)
np.linalg.inv(XTX)
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
np.linalg.inv(XTX).dot(X.T).dot(y).sum()
# 0.51
# Out:
# np.float64(0.5187709081074016)

# %% [markdown]
# ## Submit the results
#
# * Submit here: https://courses.datatalks.club/ml-zoomcamp-2025/homework/hw01
# * If your answer doesn't match options exactly, select the closest one. If exactly in between two options, select the higher value.
